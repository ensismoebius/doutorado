# %%
import sys
import pandas as pd
import numpy as np
import soundfile as sf
import matplotlib.pyplot as plt
from scipy.fftpack import dct
from scipy.signal import get_window
from IPython.display import HTML

# %%
def sa(numpyArray):
    return HTML(f"""
        <div style="max-height:300px; overflow-y:auto;">
        {pd.DataFrame(numpyArray).to_html()}
        </div>
        """)

# %%
def framesignal(x, frame_len, hop):
    N = frame_len
    L = len(x)
    num_frames = 1 + (L - N) // hop if L >= N else 1
    frames = np.zeros((num_frames, N))
    for i in range(num_frames):
        start = i * hop
        frames[i] = x[start:start+N]
    
    window = 0.5 * (1 - np.cos(2*np.pi*np.arange(N)/(N-1)))
    frames *= window
    return frames

# %%
def power_spectrum(frames, nfft):
    # frames: (F, N)
    X = np.fft.rfft(frames, n=nfft, axis=1)
    P = np.abs(X)**2
    return P  # shape (F, nfft//2+1)

# %%
def linear_filterbank(n_filters, nfft, fs):
    freqs = np.linspace(0, fs/2, nfft//2 + 1)
    # center freqs linearly
    centers = np.linspace(0, fs/2, n_filters + 2)  # include 0 and fs/2
    H = np.zeros((n_filters, len(freqs)))
    for m in range(n_filters):
        f_l, f_c, f_r = centers[m], centers[m+1], centers[m+2]
        # rising slope
        left = (freqs >= f_l) & (freqs <= f_c)
        H[m, left] = (freqs[left] - f_l) / (f_c - f_l + 1e-12)
        # falling slope
        right = (freqs >= f_c) & (freqs <= f_r)
        H[m, right] = (f_r - freqs[right]) / (f_r - f_c + 1e-12)
    return H, centers[1:-1]

# %%
def dct_type2(x):
    # simple DCT-II via explicit matrix (small M typical)
    N = x.shape[-1]
    n = np.arange(N)
    k = n.reshape((N,1))
    D = np.cos(np.pi * (2*n+1)[:,None] * k / (2*N))
    return D.dot(x)

def lfcc_from_power(P_frames, H, n_ceps):
    # P_frames: (F, K), H: (M, K)
    E = np.dot(P_frames, H.T)  # (F, M)
    E = np.maximum(E, 1e-12)
    logE = np.log(E)
    # compute DCT per frame
    ceps = np.array([dct_type2(logE[f])[:n_ceps] for f in range(logE.shape[0])])
    return ceps  # (F, n_ceps)

# %%
def smooth_spectrum(S, win_len=5):
    # simple moving average smoothing on magnitude spectrum (1D)
    kernel = np.ones(win_len)/win_len
    return np.convolve(S, kernel, mode='same')

def mgd_frame(x_frame, nfft=2048, gamma=0.4, alpha=0.4, smooth_win=5):
    N = len(x_frame)
    # zero-pad to nfft
    X = np.fft.fft(x_frame, n=nfft)
    n = np.arange(N)
    Y = np.fft.fft(x_frame * n, n=nfft)
    # numerator (real-part inner product)
    num = (X.real * Y.real + X.imag * Y.imag)
    # smooth magnitude spectrum
    S = np.abs(X)
    S_smooth = smooth_spectrum(S, win_len=smooth_win)
    denom = np.maximum(S_smooth**(2*gamma), 1e-12)
    tau = num / denom
    mgd = np.sign(tau) * (np.abs(tau)**alpha)
    return mgd[:nfft//2+1]  # return positive freqs

def mgdf_features(frames, nfft=2048, gamma=0.4, alpha=0.4, smooth_win=5, H=None, n_ceps=16):
    # frames: (F, N). compute mgd spectrum per frame, optionally apply filterbank H then DCT
    F = frames.shape[0]
    K = nfft//2+1
    mgd_spec = np.zeros((F, K))
    for i in range(F):
        mgd_spec[i] = mgd_frame(frames[i], nfft=nfft, gamma=gamma, alpha=alpha, smooth_win=smooth_win)
    if H is not None:
        # apply same linear filterbank H (or mel) then log + DCT
        E = np.dot(mgd_spec, H.T)  # (F, M)
        E = np.maximum(E, 1e-12)
        logE = np.log(np.abs(E))
        ceps = np.array([dct_type2(logE[f])[:n_ceps] for f in range(F)])
        return ceps
    else:
        return mgd_spec  # raw MGDF spectrum per frame

# %%
fs = 1024
t = np.linspace(0, 1.0, fs, endpoint=False)
# exemplo: fala-like = soma de senos (formantes) + ruído
x = 0.6*np.sin(2*np.pi*220*t) + 0.3*np.sin(2*np.pi*880*t) + 0.05*np.random.randn(len(t))

# %%
plt.plot(x)

# %%
frame_len = int(0.025*fs)
frame_len
# Out:
# 25

# %%
hop = int(0.010*fs)
hop
# Out:
# 10

# %%
frames = framesignal(x, frame_len, hop)  # (F, N)
sa(frames)
# Out:
#         <div style="max-height:300px; overflow-y:auto;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>10</th>
#       <th>11</th>
#       <th>12</th>
#       <th>13</th>
#       <th>14</th>
#       <th>15</th>
#       <th>16</th>
#       <th>17</th>
#       <th>18</th>
#       <th>19</th>
#       <th>20</th>
#       <th>21</th>
#       <th>22</th>
#       <th>23</th>
#       <th>24</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-0.0</td>
#       <td>0.006515</td>
#       <td>-0.000740</td>
#       <td>-0.081072</td>
#       <td>-0.078822</td>
#       <td>0.189237</td>
#       <td>0.416420</td>
#       <td>0.042755</td>
#       <td>-0.590573</td>
#       <td>-0.461808</td>
#       <td>0.318580</td>
#       <td>0.519516</td>
#       <td>-0.007941</td>
#       <td>-0.429322</td>
#       <td>0.070488</td>
#       <td>0.419128</td>
#       <td>-0.061695</td>
#       <td>-0.415217</td>
#       <td>-0.171196</td>
#       <td>0.221089</td>
#       <td>0.216770</td>
#       <td>-0.001846</td>
#       <td>-0.050447</td>
#       <td>-0.008353</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.0</td>
#       <td>0.009004</td>
#       <td>-0.000532</td>
#       <td>-0.063962</td>
#       <td>0.018887</td>
#       <td>0.181974</td>
#       <td>-0.041130</td>
#       <td>-0.415217</td>
#       <td>-0.256794</td>
#       <td>0.509219</td>
#       <td>0.808998</td>
#       <td>-0.012388</td>
#       <td>-0.753087</td>
#       <td>-0.481926</td>
#       <td>0.175434</td>
#       <td>0.481878</td>
#       <td>-0.066035</td>
#       <td>-0.176187</td>
#       <td>0.075098</td>
#       <td>0.181754</td>
#       <td>-0.041992</td>
#       <td>-0.099587</td>
#       <td>-0.023487</td>
#       <td>0.009524</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0</td>
#       <td>-0.000215</td>
#       <td>-0.050447</td>
#       <td>-0.071800</td>
#       <td>0.047007</td>
#       <td>0.209219</td>
#       <td>-0.044023</td>
#       <td>-0.176187</td>
#       <td>0.112647</td>
#       <td>0.418619</td>
#       <td>-0.156716</td>
#       <td>-0.668439</td>
#       <td>-0.350623</td>
#       <td>0.549484</td>
#       <td>0.829094</td>
#       <td>0.073858</td>
#       <td>-0.541654</td>
#       <td>-0.287949</td>
#       <td>0.158092</td>
#       <td>0.144956</td>
#       <td>-0.021809</td>
#       <td>-0.033606</td>
#       <td>0.015757</td>
#       <td>0.008153</td>
#       <td>-0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.0</td>
#       <td>-0.011586</td>
#       <td>-0.023487</td>
#       <td>0.081865</td>
#       <td>0.222155</td>
#       <td>0.032067</td>
#       <td>-0.361103</td>
#       <td>-0.287949</td>
#       <td>0.237138</td>
#       <td>0.333867</td>
#       <td>-0.081394</td>
#       <td>-0.225568</td>
#       <td>0.235217</td>
#       <td>0.470371</td>
#       <td>-0.064806</td>
#       <td>-0.644389</td>
#       <td>-0.328116</td>
#       <td>0.333321</td>
#       <td>0.425167</td>
#       <td>0.074263</td>
#       <td>-0.164400</td>
#       <td>-0.067682</td>
#       <td>0.016775</td>
#       <td>0.006682</td>
#       <td>-0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0
td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.0</td>
#       <td>0.001331</td>
#       <td>-0.036549</td>
#       <td>-0.034907</td>
#       <td>0.066307</td>
#       <td>0.035384</td>
#       <td>-0.220815</td>
#       <td>-0.137757</td>
#       <td>0.366710</td>
#       <td>0.652236</td>
#       <td>-0.115911</td>
#       <td>-0.807339</td>
#       <td>-0.577433</td>
#       <td>0.377191</td>
#       <td>0.672893</td>
#       <td>0.114305</td>
#       <td>-0.351502</td>
#       <td>-0.063333</td>
#       <td>0.138135</td>
#       <td>-0.020479</td>
#       <td>-0.103859</td>
#       <td>-0.048732</td>
#       <td>0.036394</td>
#       <td>0.012989</td>
#       <td>-0.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>-0.0</td>
#       <td>-0.013993</td>
#       <td>-0.038681</td>
#       <td>0.056196</td>
#       <td>0.180301</td>
#       <td>0.049628</td>
#       <td>-0.234335</td>
#       <td>-0.063333</td>
#       <td>0.207203</td>
#       <td>-0.047167</td>
#       <td>-0.387606</td>
#       <td>-0.327097</td>
#       <td>0.543304</td>
#       <td>0.749407</td>
#       <td>-0.030927</td>
#       <td>-0.836260</td>
#       <td>-0.390844</td>
#       <td>0.245824</td>
#       <td>0.342786</td>
#       <td>0.034383</td>
#       <td>-0.098478</td>
#       <td>-0.006226</td>
#       <td>0.025829</td>
#       <td>-0.000360</td>
#       <td>-0.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>-0.0</td>
#       <td>-0.005669</td>
#       <td>0.036394</td>
#       <td>0.111650</td>
#       <td>-0.008287</td>
#       <td>-0.363082</td>
#       <td>-0.260563</td>
#       <td>0.245824</td>
#       <td>0.514179</td>
#       <td>0.079191</td>
#       <td>-0.367524</td>
#       <td>-0.041791</td>
#       <td>0.3855

# %%
nfft = 2048

# %%
P = power_spectrum(frames, nfft)  # (F, K)

# %%
H, centers = linear_filterbank(n_filters=32, nfft=nfft, fs=fs)
H[0].size
# Out:
# 1025

# %%
lfcc = lfcc_from_power(P, H, n_ceps=16)  # (F, 16)
mgd_ceps = mgdf_features(frames, nfft=nfft, gamma=0.4, alpha=0.4, smooth_win=5, H=H, n_ceps=16)
# concat features per frame
feats = np.concatenate([lfcc, mgd_ceps], axis=1)  # (F, 32)
print("frames:", frames.shape, "LFCC:", lfcc.shape, "MGD-cep:", mgd_ceps.shape, "concat:", feats.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 lfcc = lfcc_from_power(P, H, n_ceps=16)  # (F, 16)
#       2 mgd_ceps = mgdf_features(frames, nfft=nfft, gamma=0.4, alpha=0.4, smooth_win=5, H=H, n_ceps=16)
#       3 # concat features per frame
#
# Cell In[5], line 15, in lfcc_from_power(P_frames, H, n_ceps)
#      13 logE = np.log(E)
#      14 # compute DCT per frame
# ---> 15 ceps = np.array([dct_type2(logE[f])[:n_ceps] for f in range(logE.shape[0])])
#      16 return ceps
#
# Cell In[5], line 7, in dct_type2(x)
#       5 k = n.reshape((N,1))
#       6 D = np.cos(np.pi * (2*n+1)[:,None] * k / (2*N))
# ----> 7 return D.dot(x)
#
# ValueError: shapes (32,1) and (32,) not aligned: 1 (dim 1) != 32 (dim 0)
